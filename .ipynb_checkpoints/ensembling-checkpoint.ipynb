# %% [markdown]
# # 8300 public score aka best result

# %%
from IPython.display import clear_output
from google.colab import drive
import os
import numpy as np
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/kaggle/finnet/last_try')
# !pip install catboost
clear_output()
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
import warnings
import os
warnings.filterwarnings('ignore')
warnings.simplefilter("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"
import numpy as np
from IPython.display import clear_output
import pandas as pd
from tqdm import tqdm_notebook
from sklearn.preprocessing import LabelEncoder, StandardScaler
from catboost import CatBoostClassifier, Pool
from sklearn.ensemble import VotingClassifier
import networkx as nx
from gensim.models import KeyedVectors
import matplotlib.pyplot as plt
import seaborn as sns
import gc

# %%
# fix seeds
s = 42
from numpy.random import seed
seed(s)

# %% [markdown]
# ## Загрузим данные

# %%
# %%time
edges = pd.read_csv('../data/edges.csv')
ids = pd.read_csv('../data/ids.csv')
vertices = pd.read_csv('../data/vertices.csv')
# Out:
# CPU times: user 2.07 s, sys: 191 ms, total: 2.26 s
# Wall time: 2.38 s

# %%
# replace old region codes with new
old_new_regions = {
    81: 59,
    85: 38,
    99: 77,   
}
vertices['region_code'] = vertices['region_code'].replace(old_new_regions)

# encode categorical vars
vertices['main_okved'] = vertices['main_okved'].astype(str)
vertices['region_code'] = vertices['region_code'].astype('uint8')
vertices['pre_main_okved'] = vertices['main_okved'].agg([lambda x: x.split(".")[0]])
vertices['post_main_okved'] = vertices['main_okved'].agg([lambda x: x.split(".")[1]])
edges['av_transaction'] = edges['value'] / edges['n_transactions']

# %%
inv_edges = edges[['id_2', 'id_1'] + edges.columns[2:].to_list()]
inv_edges.rename({'id_2': 'id_1', 'id_1': 'id_2'}, axis=1, inplace=True)
bi_edges = pd.concat([edges, inv_edges])

# %%
if 'embeddings256.pkl' not in os.listdir():
    model = KeyedVectors.load_word2vec_format("n2v256.bin")
    embs = pd.DataFrame(np.zeros((len(vertices), model.vector_size + 1)), columns=['id'] + [f"e_{i}" for i in range(model.vector_size)])

    for i in tqdm_notebook(range(1, 1534750)):
        embs.iloc[i-1, 0] = i
        if str(i) in model:
            embs.iloc[i-1, 1:] = model[str(i)]
    embs.to_pickle("/embeddings256.pkl")
else:
    embs = pd.read_pickle("embeddings256.pkl")

emb_features = list(embs.columns[embs.columns.str.startswith('e_')])

# %%
ver_w_features = vertices.copy()
ver_w_features = pd.merge(ver_w_features, embs, how='left', on='id')

# %%
feature_edges = bi_edges[~bi_edges['id_2'].isin(ids['id'])]

agg_funcs = ['mean', 'max', 'size']
agg_features = feature_edges.groupby('id_1')[['value', 'n_transactions', 'av_transaction']].agg(agg_funcs)
agg_features.columns = ['_'.join(i) for i in agg_features.columns]
agg_features.drop(['value_size', 'av_transaction_size'], axis=1, inplace=True)
agg_features_cols = agg_features.columns.to_list()
agg_features = agg_features.reset_index()

# %%
ver_w_features = pd.merge(ver_w_features, agg_features, how='left', left_on='id', right_on='id_1').drop('id_1', axis=1)

# %%
del embs, edges, vertices, inv_edges;
gc.collect()
# Out:
# 9

# %% [markdown]
# ## Обучим модель

# %%
class WorldGreatestModel(object):
    # basically, simple ensemble
    def __init__(self, estimators=None):
        self.estimators = estimators
    
    def fit(self, X, y, cat_features):
        train = Pool(X, y, cat_features=cat_features)
        for i in range(len(self.estimators)):
            self.estimators[i].fit(X, y, cat_features=cat_features)
        del train
        gc.collect()

    def predict_proba(self, X):
        preds = [self.estimators[i].predict_proba(X) for i in range(len(self.estimators))]
        preds = sum(preds) / len(self.estimators)
        return preds


def get_model(ver_id):
    tt = 'GPU'
    iters = 650
    model = WorldGreatestModel(
                    [
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s + 7, objective='Logloss',
                            verbose=350,  border_count=32,
                        ),
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s*2 + 6, objective='Logloss',
                            verbose=350,  border_count=32
                        ),
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s*3 + 5, objective='Logloss',
                            verbose=350,  border_count=32
                        ),
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s*4 + 4, objective='Logloss',
                            verbose=350,  border_count=32
                        ),
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s*5 + 3, objective='Logloss',
                            verbose=350,  border_count=32
                        ),
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s*6 + 2, objective='Logloss',
                            verbose=350,  border_count=32
                        ),
                        CatBoostClassifier(
                            iters, task_type=tt, random_state=s*7 + 1, objective='Logloss',
                            verbose=350,  border_count=32
                        ),
                        ],
                    )
    return model

# %%
num_features = emb_features + agg_features_cols
cat_features = ['main_okved', 'region_code', 'company_type', 'pre_main_okved', 'post_main_okved']
features = num_features + cat_features

n_left = [2000, 3000, 4000]
results = {n: pd.DataFrame(columns=['id_1', 'id_2', 'goodness']) for n in n_left}


for i in tqdm_notebook(ids["id"]):
    train = bi_edges[bi_edges['id_1'] == i]
    train['target'] = 1
    train = pd.merge(ver_w_features, train[['id_2', 'target']], how='left', left_on='id', right_on='id_2')
    train.drop('id_2', inplace=True, axis=1)
    train.rename({'id': 'id_2'}, axis=1, inplace=True)
    train["target"] = train["target"].fillna(0)
    
    X = train[features]
    y = train['target']
    
    model = get_model(i)
    print(f"Fitting vertice with id: {i}")
    model.fit(X, y, cat_features=cat_features)

    preds = model.predict_proba(X)[:,1]

    train['id_1'] = i
    train['goodness'] = preds
    
    res = train[train['target'] != 1].sort_values(by='goodness', ascending=False)

    for n in n_left:
        results[n] = results[n].append(res.iloc[:n][['id_1', 'id_2', 'goodness']], ignore_index=True, sort=False)

    del res, preds, train, y, X, model
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Fitting vertice with id: 524354
# Learning rate set to 0.5
# 0:	learn: 0.0372811	total: 46.8ms	remaining: 0us
# Fitting vertice with id: 61537
# Learning rate set to 0.5
# 0:	learn: 0.0211685	total: 33ms	remaining: 0us
# Fitting vertice with id: 1142564
# Learning rate set to 0.5
# 0:	learn: 0.0195481	total: 35.8ms	remaining: 0us
# Fitting vertice with id: 300432
# Learning rate set to 0.5
# 0:	learn: 0.0318114	total: 33.3ms	remaining: 0us
# Fitting vertice with id: 83777
# Learning rate set to 0.5
# 0:	learn: 0.0253402	total: 32ms	remaining: 0us
# Fitting vertice with id: 206473
# Learning rate set to 0.5
# 0:	learn: 0.0257313	total: 34.3ms	remaining: 0us
# Fitting vertice with id: 58408
# Learning rate set to 0.5
# 0:	learn: 0.0345947	total: 31.9ms	remaining: 0us
# Fitting vertice with id: 776150
# Learning rate set to 0.5
# 0:	learn: 0.0324617	total: 32.5ms	remaining: 0us
# Fitting vertice with id: 1292407
# Learning rate set to 0.5
# 0:	learn: 0.0280509	total: 34ms	remaining: 0us
# Fitting vertice with id: 361401
# Learning rate set to 0.5
# 0:	learn: 0.0294082	total: 32.1ms	remaining: 0us
# Fitting vertice with id: 1301544
# Learning rate set to 0.5
# 0:	learn: 0.0293923	total: 33.7ms	remaining: 0us
# Fitting vertice with id: 1203323
# Learning rate set to 0.5
# 0:	learn: 0.0292152	total: 34.6ms	remaining: 0us
# Fitting vertice with id: 1209828
# Learning rate set to 0.5
# 0:	learn: 0.0248911	total: 32.5ms	remaining: 0us
# Fitting vertice with id: 341670
# Learning rate set to 0.5
# 0:	learn: 0.0305542	total: 31.4ms	remaining: 0us
# Fitting vertice with id: 83818
# Learning rate set to 0.5
# 0:	learn: 0.0229243	total: 33.7ms	remaining: 0us
# Fitting vertice with id: 1189202
# Learning rate set to 0.5
# 0:	learn: 0.0277924	total: 31ms	remaining: 0us
# Fitting vertice with id: 1434836
# Learning rate set to 0.5
# 0:	learn: 0.0294391	total: 33.7ms	remaining: 0us
# Fitting vertice with id: 929264
# Learning rate set to 0.5
# 0:	learn: 0.0253998	total: 32.1ms	remaining: 0us
# Fitting vertice with id: 1263393
# Learning rate set to 0.5
# 0:	learn: 0.0248114	total: 31.6ms	remaining: 0us
# Fitting vertice with id: 1342003
# Learning rate set to 0.5
# 0:	learn: 0.0254261	total: 34.7ms	remaining: 0us
# Fitting vertice with id: 1063763
# Learning rate set to 0.5
# 0:	learn: 0.0255689	total: 34.1ms	remaining: 0us
# Fitting vertice with id: 41216
# Learning rate set to 0.5
# 0:	learn: 0.0220118	total: 31.5ms	remaining: 0us
# Fitting vertice with id: 1227912
# Learning rate set to 0.5
# 0:	learn: 0.0250568	total: 34.2ms	remaining: 0us
# Fitting vertice with id: 983180
# Learning rate set to 0.5
# 0:	learn: 0.0244222	total: 32.7ms	remaining: 0us
# Fitting vertice with id: 324065
# Learning rate set to 0.5
# 0:	learn: 0.0197360	total: 32.3ms	remaining: 0us
# Fitting vertice with id: 258315
# Learning rate set to 0.5
# 0:	learn: 0.0201945	total: 34ms	remaining: 0us
# Fitting vertice with id: 1160709
# Learning rate set to 0.5
# 0:	learn: 0.0252919	total: 21.9ms	remaining: 0us
# Fitting vertice with id: 1443535
# Learning rate set to 0.5
# 0:	learn: 0.0227046	total: 30.8ms	remaining: 0us
# Fitting vertice with id: 214507
# Learning rate set to 0.5
# 0:	learn: 0.0207295	total: 33.7ms	remaining: 0us
# Fitting vertice with id: 1319172
# Learning rate set to 0.5
# 0:	learn: 0.0209732	total: 34.1ms	remaining: 0us
# Fitting vertice with id: 1147550
# Learning rate set to 0.5
# 0:	learn: 0.0091106	total: 32.4ms	remaining: 0us
# Fitting vertice with id: 785334
# Learning rate set to 0.5
# 0:	learn: 0.0227832	total: 33.5ms	remaining: 0us
# Fitting vertice with id: 640944
# Learning rate set to 0.5
# 0:	learn: 0.0195524	total: 31.1ms	remaining: 0us
# Fitting vertice with id: 1154568
# Learning rate set to 0.5
# 0:	learn: 0.0158151	total: 32.2ms	remaining: 0us
# Fitting vertice with id: 1427428
# Learning rate set to 0.5
# 0:	learn: 0.0233679	total: 34.1ms	remaining: 0us
# Fitting vertice with id: 409925
# Learning rate set to 0.5
# 0:	learn: 0.0233550	total: 32.2ms	remaining: 0us
# Fitting vertice with id: 1052575
# Learning rate set to 0.5
# 0:	learn: 0.0245981	total: 22.3ms	remaining: 0us
# Fitting vertice with id: 258675
# Learning rate set to 0.5
# 0:	learn: 0.0235699	total: 33.8ms	remaining: 0us
# Fitting vertice with id: 1136487
# Learning rate set to 0.5
# 0:	learn: 0.0165630	total: 31.5ms	remaining: 0us
# Fitting vertice with id: 722645
# Learning rate set to 0.5
# 0:	learn: 0.0233639	total: 21.6ms	remaining: 0us
# Fitting vertice with id: 955991
# Learning rate set to 0.5
# 0:	learn: 0.0201867	total: 32.2ms	remaining: 0us
# Fitting vertice with id: 1408687
# Learning rate set to 0.5
# 0:	learn: 0.0202515	total: 32.6ms	remaining: 0us
# Fitting vertice with id: 676805
# Learning rate set to 0.5
# 0:	learn: 0.0221140	total: 30.5ms	remaining: 0us
# Fitting vertice with id: 331678
# Learning rate set to 0.5
# 0:	learn: 0.0200412	total: 33.1ms	remaining: 0us
# Fitting vertice with id: 1378192
# Learning rate set to 0.5
# 0:	learn: 0.0212208	total: 30.4ms	remaining: 0us
# Fitting vertice with id: 1289618
# Learning rate set to 0.5
# 0:	learn: 0.0209010	total: 36.4ms	remaining: 0us
# Fitting vertice with id: 227665
# Learning rate set to 0.5
# 0:	learn: 0.0184628	total: 31.1ms	remaining: 0us
# Fitting vertice with id: 194554
# Learning rate set to 0.5
# 0:	learn: 0.0208808	total: 33.1ms	remaining: 0us
# Fitting vertice with id: 1380777
# Learning rate set to 0.5
# 0:	learn: 0.0185313	total: 34.6ms	remaining: 0us
# Fitting vertice with id: 1297265
# Learning rate set to 0.5
# 0:	learn: 0.0201911	total: 32.9ms	remaining: 0us
# Fitting vertice with id: 1292275
# Learning rate set to 0.5
# 0:	learn: 0.0174756	total: 35.7ms	remaining: 0us
# Fitting vertice with id: 1356407
# Learning rate set to 0.5
# 0:	learn: 0.0192217	total: 35.7ms	remaining: 0us
# Fitting vertice with id: 846476
# Learning rate set to 0.5
# 0:	learn: 0.0185391	total: 31.6ms	remaining: 0us
# Fitting vertice with id: 567406
# Learning rate set to 0.5
# 0:	learn: 0.0205608	total: 35.1ms	remaining: 0us
# Fitting vertice with id: 127685
# Learning rate set to 0.5
# 0:	learn: 0.0144381	total: 34.8ms	remaining: 0us
# Fitting vertice with id: 1392226
# Learning rate set to 0.5
# 0:	learn: 0.0174698	total: 32.8ms	remaining: 0us
# Fitting vertice with id: 434248
# Learning rate set to 0.5
# 0:	learn: 0.0189284	total: 31.3ms	remaining: 0us
# Fitting vertice with id: 1452068
# Learning rate set to 0.5
# 0:	learn: 0.0196885	total: 33.3ms	remaining: 0us
# Fitting vertice with id: 713665
# Learning rate set to 0.5
# 0:	learn: 0.0201641	total: 30.7ms	remaining: 0us
# Fitting vertice with id: 391589
# Learning rate set to 0.5
# 0:	learn: 0.0206361	total: 31.9ms	remaining: 0us
# Fitting vertice with id: 1487070
# Learning rate set to 0.5
# 0:	learn: 0.0133514	total: 32.8ms	remaining: 0us
# Fitting vertice with id: 831789
# Learning rate set to 0.5
# 0:	learn: 0.0169402	total: 32.8ms	remaining: 0us
# Fitting vertice with id: 800360
# Learning rate set to 0.5
# 0:	learn: 0.0167206	total: 33.6ms	remaining: 0us
# Fitting vertice with id: 51755
# Learning rate set to 0.5
# 0:	learn: 0.0208134	total: 21.7ms	remaining: 0us
# Fitting vertice with id: 1500415
# Learning rate set to 0.5
# 0:	learn: 0.0205989	total: 31.2ms	remaining: 0us
# Fitting vertice with id: 596221
# Learning rate set to 0.5
# 0:	learn: 0.0179310	total: 33.8ms	remaining: 0us
# Fitting vertice with id: 641486
# Learning rate set to 0.5
# 0:	learn: 0.0196065	total: 32.8ms	remaining: 0us
# Fitting vertice with id: 1331069
# Learning rate set to 0.5
# 0:	learn: 0.0207584	total: 30.2ms	remaining: 0us
# Fitting vertice with id: 310694
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a070f05bebc4> in <module>()
#      20     model = get_model(i)
#      21     print(f"Fitting vertice with id: {i}")
# ---> 22     model.fit(X, y, cat_features=cat_features)
#      23
#      24     preds = model.predict_proba(X)[:,1]
#
# <ipython-input-12-87542e021514> in fit(self, X, y, cat_features)
#       7         train = Pool(X, y, cat_features=cat_features)
#       8         for i in range(len(self.estimators)):
# ----> 9             self.estimators[i].fit(X, y, cat_features=cat_features)
#      10         del train
#      11         gc.collect()
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in fit(self, X, y, cat_features, text_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    3995         self._fit(X, y, cat_features, text_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    3996                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 3997                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    3998         return self
#    3999
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in _fit(self, X, y, cat_features, text_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1729             use_best_model, eval_set, verbose, logging_level, plot,
#    1730             column_description, verbose_eval, metric_period, silent, early_stopping_rounds,
# -> 1731             save_snapshot, snapshot_file, snapshot_interval, init_model
#    1732         )
#    1733         params = train_params["params"]
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in _prepare_train_params(self, X, y, cat_features, text_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1617
#    1618         train_pool = _build_train_pool(X, y, cat_features, text_features, pairs, sample_weight, group_id,
# -> 1619                                        group_weight, subgroup_id, pairs_weight, baseline, column_description)
#    1620         if train_pool.is_empty_:
#    1621             raise CatBoostError("X is empty.")
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in _build_train_pool(X, y, cat_features, text_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, column_description)
#     955             raise CatBoostError("y has not initialized in fit(): X is not catboost.Pool object, y must be not None in fit().")
#     956         train_pool = Pool(X, y, cat_features=cat_features, text_features=text_features, pairs=pairs, weight=sample_weight, group_id=group_id,
# --> 957                           group_weight=group_weight, subgroup_id=subgroup_id, pairs_weight=pairs_weight, baseline=baseline)
#     958     return train_pool
#     959
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in __init__(self, data, label, cat_features, text_features, column_description, pairs, delimiter, has_header, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     432                     )
#     433
# --> 434                 self._init(data, label, cat_features, text_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     435         super(Pool, self).__init__()
#     436
#
# /usr/local/lib/python3.6/dist-packages/catboost/core.py in _init(self, data, label, cat_features, text_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     936             baseline = np.reshape(baseline, (samples_count, -1))
#     937             self._check_baseline_shape(baseline, samples_count)
# --> 938         self._init_pool(data, label, cat_features, text_features, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, feature_names, thread_count)
#     939
#     940
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_pool()
#
# _catboost.pyx in _catboost._PoolBase._init_features_order_layout_pool()
#
# _catboost.pyx in _catboost._set_features_order_data_pd_data_frame()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in iteritems(self)
#     899     @Appender(_shared_docs["items"])
#     900     def iteritems(self) -> Iterable[Tuple[Optional[Hashable], Series]]:
# --> 901         yield from self.items()
#     902
#     903     def iterrows(self) -> Iterable[Tuple[Optional[Hashable], Series]]:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in items(self)
#     892         if self.columns.is_unique and hasattr(self, "_item_cache"):
#     893             for k in self.columns:
# --> 894                 yield k, self._get_item_cache(k)
#     895         else:
#     896             for i, k in enumerate(self.columns):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Результат готов к отправке

# %%
def drop_same_edges(res):
    res = nx.to_pandas_edgelist(nx.from_pandas_edgelist(res, 'id_1', 'id_2', 'goodness')).rename({'source':'id_1', 'target':'id_2'}, axis=1)
    return res 

def write_sub(res, fp='subs/submission.csv'):
    res.sort_values(by='goodness', ascending=False)[['id_1', 'id_2']].head(100000).to_csv(fp, index=False)

# %%
fp = 'subs/ensemble4_700iters_iloc{}.csv'
vertices = pd.read_csv('../data/vertices.csv')

for n in n_left:
    cfp = fp.format(n)
    write_sub(drop_same_edges(results[n]), cfp)
    s = pd.read_csv(cfp)
    ie = s[['id_2', 'id_1'] + s.columns[2:].to_list()]
    ie.rename({'id_2': 'id_1', 'id_1': 'id_2'}, axis=1, inplace=True)
    be = pd.concat([s, ie])
    b = be[be['id_1'].isin(ids['id'])]['id_1'].value_counts().reset_index().rename({'index': 'id', 'id_1' :'edges_added'}, axis=1)
    a = bi_edges.groupby('id_1')['n_transactions'].size().reset_index().rename({'id_1' :'id', 'n_transactions': 'edges_before'}, axis=1)
    a = a[a['id'].isin(ids['id'])]
    df = pd.merge(a, b, on='id')
    df['edges_after'] = df['edges_before'] + df['edges_added']
    df = pd.merge(df, vertices, on='id')
    print(n, 'left')
    print(df.to_string())
    print('\n\n\n')
# Out:
# 2000 left
#          id  edges_before  edges_added  edges_after  main_okved  region_code company_type
# 0     41216           977         2001         2978       47.54           66   Individual
# 1     55389           572            1          573       46.60           66      Limited
# 2     61537          2246         2000         4246       46.66           66      Limited
# 3     83777          1618         2000         3618       71.20           16      Limited
# 4     83818          1255         2000         3255       63.11           77      Limited
# 5    127685           655         2000         2655       63.11           55      Limited
# 6    194554           723         2000         2723       63.11           77      Limited
# 7    206473          1543         2000         3543       63.11           77      Limited
# 8    214507           837         2000         2837       69.20           77   Individual
# 9    227665           718         2000         2718       46.72           54      Limited
# 10   258315           833         2000         2833       70.22           47   Individual
# 11   300432          1709         2000         3709       63.11           66      Limited
# 12   324065           830         2000         2830       18.12           77   Individual
# 13   331678           708         2000         2708       17.20           78      Limited
# 14   341670          1394         2000         3394       46.43           12   Individual
# 15   361401          1463         2001         3464       49.40           59      Limited
# 16   386565           567            1          568       62.00           59      Limited
# 17   391589           647         1365         2012       46.74           77      Limited
# 18   409925           793          355         1148       46.73           78      Limited
# 19   434248           636         2000         2636       61.10           77      Limited
# 20   524354          2971         2000         4971       62.01           77      Limited
# 21   567406           686          160          846       62.01           77      Limited
# 22   596221           630         2000         2630       46.72           52      Limited
# 23   640944           805         2000         2805       46.75           66      Limited
# 24   641486           620          782         1402       53.20           77      Limited
# 25   676805           712          137          849       46.73           74      Limited
# 26   713665           646          138          784       47.91           78      Limited
# 27   785334           843         2000         2843       73.11           77      Limited
# 28   800360           650         2000         2650       46.43           78      Limited
# 29   831789           672         2000         2672       86.10           77      Limited
# 30   846476           669           48          717       13.30           50   Individual
# 31   929264          1039         2000         3039       46.69           77      Limited
# 32   955991           762         2001         2763       79.11           77      Limited
# 33   966969           546            1          547       46.90           66      Limited
# 34   983180           912         1488         2400       46.90           77      Limited
# 35  1025839           541            2          543       49.40           77      Limited
# 36  1036225           534            1          535       45.31           26      Limited
# 37  1063763          1001          919         1920       46.73           77   Individual
# 38  1136487           766         2002         2768       46.51           66      Limited
# 39  1142564          1930         2000         3930       63.11           77      Limited
# 40  1147550           775         2001         2776       62.09           39      Limited
# 41  1154568           801         2000         2801       46.74           66      Limited
# 42  1189202          1255         2000         3255       46.65           78      Limited
# 43  1203323          1439         2000         3439       62.01           66      Limited
# 44  1209828          1480         2000         3480       63.11           66      Limited
# 45  1227912           925         2000         2925       62.01           77      Limited
# 46  1263393          1043         2000         3043       47.91           78      Limited
# 47  1292275           678         2000         2678       73.11           66      Limited
# 48  1292407          1523         2000         3523       62.01           78      Limited
